# %%
# %pip install lionweb-python
# %pip install pydantic
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 36.2 MB/s eta 0:00:00
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [pydantic]━━ 4/5 [pydantic]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from lionwebpython.repoclient.repo_client import RepoClient

rc = RepoClient(repo_url="http://localhost:3005", repository_name="4_idioms_identified")

print("# Repositories")
print(rc.list_repositories())

print("# Partitions")
print(rc.list_partitions())
# Out:
# # Repositories
# [RepositoryConfiguration(name='default', lionweb_version=<LionWebVersion.V2023_1: '2023.1'>, history=False), RepositoryConfiguration(name='4_idioms_identified', lionweb_version=<LionWebVersion.V2023_1: '2023.1'>, history=False)]
# # Partitions
# ...
